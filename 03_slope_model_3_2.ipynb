# %% [markdown]
# model 3-2で次数の期待値$l$の$k$-$l$プロットにおける傾き

# %% [markdown]
# $$E(p(r)) = -r^{2} + 2r$$

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

r = np.linspace(0., 1., 100)
plt.plot(r, -r**2+2*r)
plt.xlabel(r'$r$')
plt.ylabel(r'$E(p(x,r))$')
plt.show()
